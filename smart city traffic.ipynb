# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ARSHI ANSARI\Downloads\lucknow_traffic_cleaned.csv")

# %%
df.head()
# Out:
#          Date  Hour     Location  Queue_Density  Stop_Density  \
# 0  2020-09-01     0   Hazratganj             15             8
# 1  2020-09-02     1     Alambagh             17            10
# 2  2020-09-03     2  Gomti Nagar             19            12
# 3  2020-09-04     3     Charbagh             21            11
# 4  2020-09-05     4   Hazratganj             19            13
#
#    Accidents_Reported  Fatalities
# 0                   0           0
# 1                   1           1
# 2                   2           2
# 3                   3           0
# 4                   4           1

# %%
df.dropna()
# Out:
#           Date  Hour     Location  Queue_Density  Stop_Density  \
# 0   2020-09-01     0   Hazratganj             15             8
# 1   2020-09-02     1     Alambagh             17            10
# 2   2020-09-03     2  Gomti Nagar             19            12
# 3   2020-09-04     3     Charbagh             21            11
# 4   2020-09-05     4   Hazratganj             19            13
# 5   2020-09-06     5     Alambagh             21            10
# 6   2020-09-07     6  Gomti Nagar             17             9
# 7   2020-09-08     7     Charbagh             19            11
# 8   2020-09-09     8   Hazratganj             17            13
# 9   2020-09-10     9     Alambagh             19            12
# 10  2020-09-11    10  Gomti Nagar             21             9
# 11  2020-09-12    11     Charbagh             23            11
# 12  2020-09-13    12   Hazratganj             15            10
# 13  2020-09-14    13     Alambagh             17            12
# ...

# %%
df.tail()
# Out:
#           Date  Hour     Location  Queue_Density  Stop_Density  \
# 35  2020-10-06    11     Charbagh             23            10
# 36  2020-10-07    12   Hazratganj             15             9
# 37  2020-10-08    13     Alambagh             17            11
# 38  2020-10-09    14  Gomti Nagar             19            13
# 39  2020-10-10    15     Charbagh             21            12
#
#     Accidents_Reported  Fatalities
# 35                   5           2
# 36                   0           0
# 37                   1           1
# 38                   2           2
# 39                   3           0

# %%
plt.bar(df['Hour'],df['Accidents_Reported'])
plt.xlabel("Hour")
plt.ylabel("Accidents_Reported")
plt.show()

# %%
sns.boxplot(x="Hour",y="Location",data=df)
plt.show()

# %%
df.head()
plt.scatter(x="Location",y="Accidents_Reported",marker="*", data=df)

# %%
sns.boxplot(x="Queue_Density", y="Stop_Density", data=df)
plt.title("Traffic by Day of Week")
plt.xticks(rotation=40)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Date', 'Hour', 'Location', 'Queue_Density', 'Stop_Density',
#        'Accidents_Reported', 'Fatalities'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date  Hour     Location  Queue_Density  Stop_Density  \
# 0  2020-09-01     0   Hazratganj             15             8
# 1  2020-09-02     1     Alambagh             17            10
# 2  2020-09-03     2  Gomti Nagar             19            12
# 3  2020-09-04     3     Charbagh             21            11
# 4  2020-09-05     4   Hazratganj             19            13
#
#    Accidents_Reported  Fatalities
# 0                   0           0
# 1                   1           1
# 2                   2           2
# 3                   3           0
# 4                   4           1

# %%
plt.figure(figsize = (5,5))
plt.hist(df["Accidents_Reported"])
plt.title("accident report")
plt.xlabel("accidents")
plt.ylabel("no. of hrs")
plt.show()

# %%
df["Fatalities"].values
# Out:
# array([0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0,
#        1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0, 1, 2, 0])

# %%
df["Fatalities"].value_counts()
# Out:
# Fatalities
# 0    14
# 1    13
# 2    13
# Name: count, dtype: int64

# %%
sns.histplot(x="Hour",y="Accidents_Reported",data=df)
plt.show()
